# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
from datetime import datetime
from citipy import citipy
import time
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e610b5fb6160ca5d8ff58e225f72001f

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city + '&units=imperial'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
            pass
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
            pass
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | kruisfontein
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | nuevo casas grandes
# Processing Record 11 of Set 1 | vera cruz
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | samana
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 1 | okahandja
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | ilheus
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | zheleznodorozhnyy
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | toda bhim
# City not found. Skipping...
# Processing Record 25 of Set 1 | poum
# Processing Record 26 of Set 1 | burkhala
# City not found. Skipping...
# Processing Record 27 of Set 1 | puerto leguizamo
# Processing Record 28 of Set 1 | chokwe
# City not found. Skipping...
# Processing Record 29 of Set 1 | lethem
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | gamba
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | manadhoo
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | narsaq
# Processing Record 38 of Set 1 | putina
# Processing Record 39 of Set 1 | moche
# Processing Record 40 of Set 1 | akyab
# City not found. Skipping...
# Processing Record 41 of Set 1 | prince rupert
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | aksu
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | nongpoh
# Processing Record 49 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | manicore
# Processing Record 2 of Set 2 | umba
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | same
# Processing Record 5 of Set 2 | kimbe
# Processing Record 6 of Set 2 | salta
# Processing Record 7 of Set 2 | atar
# Processing Record 8 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 2 | seoul
# Processing Record 10 of Set 2 | necochea
# Processing Record 11 of Set 2 | avera
# Processing Record 12 of Set 2 | blagoveshchensk
# Processing Record 13 of Set 2 | australind
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | bulaevo
# Processing Record 19 of Set 2 | vostok
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | saint-augustin
# Processing Record 22 of Set 2 | gat
# Processing Record 23 of Set 2 | portland
# Processing Record 24 of Set 2 | chicama
# Processing Record 25 of Set 2 | yangambi
# Processing Record 26 of Set 2 | fatsa
# Processing Record 27 of Set 2 | bambous virieux
# Processing Record 28 of Set 2 | cap-aux-meules
# Processing Record 29 of Set 2 | muisne
# Processing Record 30 of Set 2 | zilair
# Processing Record 31 of Set 2 | touba
# Processing Record 32 of Set 2 | katsuura
# Processing Record 33 of Set 2 | fort saint james
# Processing Record 34 of Set 2 | fort nelson
# Processing Record 35 of Set 2 | monroe
# Processing Record 36 of Set 2 | tomohon
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | saint-pierre
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 41 of Set 2 | krasnaya gorbatka
# Processing Record 42 of Set 2 | saint-francois
# Processing Record 43 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | babadag
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | waw
# City not found. Skipping...
# Processing Record 50 of Set 2 | itaituba
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | ballina
# Processing Record 3 of Set 3 | severo-kurilsk
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | nuuk
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | san vicente
# Processing Record 9 of Set 3 | jacareacanga
# Processing Record 10 of Set 3 | mitsamiouli
# Processing Record 11 of Set 3 | athabasca
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | buala
# Processing Record 21 of Set 3 | soe
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | zhuhai
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | tacuati
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | magadan
# Processing Record 29 of Set 3 | fallon
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | horta
# Processing Record 34 of Set 3 | oistins
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | bossangoa
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | champerico
# Processing Record 39 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 3 | sitges
# Processing Record 41 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 3 | bad sackingen
# Processing Record 43 of Set 3 | lagunas
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | palencia
# Processing Record 46 of Set 3 | chernyshevskiy
# Processing Record 47 of Set 3 | pombia
# Processing Record 48 of Set 3 | margarita
# Processing Record 49 of Set 3 | saldanha
# Processing Record 50 of Set 3 | pyshchug
# Processing Record 1 of Set 4 | santa barbara
# Processing Record 2 of Set 4 | koygorodok
# Processing Record 3 of Set 4 | katangli
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | pag
# Processing Record 6 of Set 4 | ketchikan
# Processing Record 7 of Set 4 | cascais
# Processing Record 8 of Set 4 | grimari
# City not found. Skipping...
# Processing Record 9 of Set 4 | sakakah
# City not found. Skipping...
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | yeehaw junction
# City not found. Skipping...
# Processing Record 12 of Set 4 | denpasar
# Processing Record 13 of Set 4 | abha
# Processing Record 14 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 4 | acapulco
# Processing Record 16 of Set 4 | vaini
# Processing Record 17 of Set 4 | sao filipe
# Processing Record 18 of Set 4 | saint-georges
# Processing Record 19 of Set 4 | bartlesville
# Processing Record 20 of Set 4 | nikolskoye
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | corpus christi
# Processing Record 23 of Set 4 | mount isa
# Processing Record 24 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | bathsheba
# Processing Record 27 of Set 4 | naron
# Processing Record 28 of Set 4 | lodja
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | presidencia roque saenz pena
# Processing Record 34 of Set 4 | saundatti yellamma
# City not found. Skipping...
# Processing Record 35 of Set 4 | madanapalle
# Processing Record 36 of Set 4 | candawaga
# City not found. Skipping...
# Processing Record 37 of Set 4 | tazovskiy
# Processing Record 38 of Set 4 | east london
# Processing Record 39 of Set 4 | sokolo
# Processing Record 40 of Set 4 | hamilton
# Processing Record 41 of Set 4 | jiuquan
# Processing Record 42 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 4 | usinsk
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | kapaa
# Processing Record 46 of Set 4 | brandon
# Processing Record 47 of Set 4 | ischia
# Processing Record 48 of Set 4 | clyde river
# Processing Record 49 of Set 4 | tucuman
# Processing Record 50 of Set 4 | bengkulu
# City not found. Skipping...
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | tefe
# Processing Record 3 of Set 5 | tiznit
# Processing Record 4 of Set 5 | yerbogachen
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | marawi
# Processing Record 7 of Set 5 | kampong thum
# Processing Record 8 of Set 5 | tilichiki
# Processing Record 9 of Set 5 | kungurtug
# Processing Record 10 of Set 5 | paamiut
# Processing Record 11 of Set 5 | inhambane
# Processing Record 12 of Set 5 | noumea
# Processing Record 13 of Set 5 | waingapu
# Processing Record 14 of Set 5 | cheremukhovo
# Processing Record 15 of Set 5 | coihaique
# Processing Record 16 of Set 5 | margate
# Processing Record 17 of Set 5 | aklavik
# Processing Record 18 of Set 5 | vylkove
# Processing Record 19 of Set 5 | novikovo
# Processing Record 20 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 5 | fortuna
# Processing Record 22 of Set 5 | namatanai
# Processing Record 23 of Set 5 | luau
# Processing Record 24 of Set 5 | hilo
# Processing Record 25 of Set 5 | ode
# Processing Record 26 of Set 5 | severodvinsk
# Processing Record 27 of Set 5 | tecoanapa
# Processing Record 28 of Set 5 | lac-megantic
# Processing Record 29 of Set 5 | charters towers
# Processing Record 30 of Set 5 | itarema
# Processing Record 31 of Set 5 | mao
# Processing Record 32 of Set 5 | makung
# City not found. Skipping...
# Processing Record 33 of Set 5 | diapaga
# Processing Record 34 of Set 5 | teahupoo
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | batavia
# Processing Record 37 of Set 5 | oakdale
# Processing Record 38 of Set 5 | muravlenko
# Processing Record 39 of Set 5 | malakal
# City not found. Skipping...
# Processing Record 40 of Set 5 | ambon
# Processing Record 41 of Set 5 | el faiyum
# City not found. Skipping...
# Processing Record 42 of Set 5 | suchitlan
# Processing Record 43 of Set 5 | rawah
# City not found. Skipping...
# Processing Record 44 of Set 5 | huarmey
# Processing Record 45 of Set 5 | uribia
# Processing Record 46 of Set 5 | vangaindrano
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | la ronge
# Processing Record 50 of Set 5 | ponta do sol
# Processing Record 1 of Set 6 | olinda
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | provost
# Processing Record 4 of Set 6 | hirado
# Processing Record 5 of Set 6 | matamoros
# Processing Record 6 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 8 of Set 6 | kuusamo
# Processing Record 9 of Set 6 | pineville
# Processing Record 10 of Set 6 | lata
# Processing Record 11 of Set 6 | vanimo
# Processing Record 12 of Set 6 | huntington
# Processing Record 13 of Set 6 | kamaishi
# Processing Record 14 of Set 6 | bam
# Processing Record 15 of Set 6 | luzhou
# Processing Record 16 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | viedma
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | whyalla
# Processing Record 21 of Set 6 | tarakan
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | batagay-alyta
# Processing Record 24 of Set 6 | eydhafushi
# Processing Record 25 of Set 6 | kendari
# Processing Record 26 of Set 6 | straseni
# Processing Record 27 of Set 6 | le port
# Processing Record 28 of Set 6 | ust-nera
# Processing Record 29 of Set 6 | lebu
# Processing Record 30 of Set 6 | aleksandrov gay
# Processing Record 31 of Set 6 | teya
# Processing Record 32 of Set 6 | kibala
# Processing Record 33 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 34 of Set 6 | jizan
# Processing Record 35 of Set 6 | cherskiy
# Processing Record 36 of Set 6 | tovste
# Processing Record 37 of Set 6 | port macquarie
# Processing Record 38 of Set 6 | wamba
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | yumen
# Processing Record 41 of Set 6 | liuhe
# Processing Record 42 of Set 6 | morros
# Processing Record 43 of Set 6 | axim
# Processing Record 44 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 6 | rock sound
# Processing Record 46 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 6 | lentekhi
# Processing Record 48 of Set 6 | ilulissat
# Processing Record 49 of Set 6 | grand gaube
# Processing Record 50 of Set 6 | rorvik
# Processing Record 1 of Set 7 | celestun
# Processing Record 2 of Set 7 | bayir
# Processing Record 3 of Set 7 | palaia fokaia
# Processing Record 4 of Set 7 | tura
# Processing Record 5 of Set 7 | yeppoon
# Processing Record 6 of Set 7 | ampanihy
# Processing Record 7 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | angul
# Processing Record 11 of Set 7 | fukue
# Processing Record 12 of Set 7 | casma
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | longyearbyen
# Processing Record 15 of Set 7 | khatanga
# Processing Record 16 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 7 | kismayo
# City not found. Skipping...
# Processing Record 18 of Set 7 | apache junction
# Processing Record 19 of Set 7 | houma
# Processing Record 20 of Set 7 | grootfontein
# Processing Record 21 of Set 7 | maraa
# Processing Record 22 of Set 7 | santa luzia
# Processing Record 23 of Set 7 | cairns
# Processing Record 24 of Set 7 | batyrevo
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | keti bandar
# Processing Record 27 of Set 7 | torbay
# Processing Record 28 of Set 7 | severomorsk
# Processing Record 29 of Set 7 | resistencia
# Processing Record 30 of Set 7 | kerman
# Processing Record 31 of Set 7 | the valley
# Processing Record 32 of Set 7 | castro
# Processing Record 33 of Set 7 | pontianak
# Processing Record 34 of Set 7 | talnakh
# Processing Record 35 of Set 7 | leeton
# Processing Record 36 of Set 7 | sur
# Processing Record 37 of Set 7 | kualakapuas
# Processing Record 38 of Set 7 | pedasi
# Processing Record 39 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 40 of Set 7 | carndonagh
# Processing Record 41 of Set 7 | alofi
# Processing Record 42 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 7 | chernoyerkovskaya
# Processing Record 44 of Set 7 | namtsy
# Processing Record 45 of Set 7 | wismar
# Processing Record 46 of Set 7 | bubaque
# Processing Record 47 of Set 7 | cam ranh
# Processing Record 48 of Set 7 | road town
# Processing Record 49 of Set 7 | salinopolis
# Processing Record 50 of Set 7 | baculin
# Processing Record 1 of Set 8 | beian
# Processing Record 2 of Set 8 | wajima
# Processing Record 3 of Set 8 | punata
# Processing Record 4 of Set 8 | waipawa
# Processing Record 5 of Set 8 | paita
# Processing Record 6 of Set 8 | fukuma
# Processing Record 7 of Set 8 | alta floresta
# Processing Record 8 of Set 8 | umiray
# Processing Record 9 of Set 8 | ust-koksa
# Processing Record 10 of Set 8 | husavik
# Processing Record 11 of Set 8 | jijiga
# Processing Record 12 of Set 8 | niquelandia
# Processing Record 13 of Set 8 | iracoubo
# Processing Record 14 of Set 8 | kalaleh
# Processing Record 15 of Set 8 | ribeira grande
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 18 of Set 8 | dunedin
# Processing Record 19 of Set 8 | akkudah
# City not found. Skipping...
# Processing Record 20 of Set 8 | anloga
# Processing Record 21 of Set 8 | camacha
# Processing Record 22 of Set 8 | sitka
# Processing Record 23 of Set 8 | brae
# Processing Record 24 of Set 8 | shieli
# Processing Record 25 of Set 8 | morondava
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | donghai
# Processing Record 28 of Set 8 | shar
# Processing Record 29 of Set 8 | asau
# City not found. Skipping...
# Processing Record 30 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | cukai
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | atlantic city
# City not found. Skipping...
# Processing Record 34 of Set 8 | siyabuswa
# Processing Record 35 of Set 8 | maicao
# Processing Record 36 of Set 8 | labuhan
# Processing Record 37 of Set 8 | vista hermosa
# Processing Record 38 of Set 8 | zhigansk
# Processing Record 39 of Set 8 | srandakan
# Processing Record 40 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 8 | comodoro rivadavia
# Processing Record 42 of Set 8 | sunland park
# Processing Record 43 of Set 8 | juybar
# Processing Record 44 of Set 8 | turinskaya sloboda
# Processing Record 45 of Set 8 | falkenberg
# Processing Record 46 of Set 8 | goderich
# Processing Record 47 of Set 8 | durusu
# Processing Record 48 of Set 8 | yar-sale
# Processing Record 49 of Set 8 | havelock
# Processing Record 50 of Set 8 | sertolovo
# Processing Record 1 of Set 9 | les cayes
# Processing Record 2 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 9 | joshimath
# Processing Record 4 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | ylivieska
# Processing Record 6 of Set 9 | veinticinco de mayo
# Processing Record 7 of Set 9 | sayyan
# Processing Record 8 of Set 9 | san policarpo
# Processing Record 9 of Set 9 | bolshoy uluy
# City not found. Skipping...
# Processing Record 10 of Set 9 | port hedland
# Processing Record 11 of Set 9 | pueblo nuevo vinas
# Processing Record 12 of Set 9 | chastyye
# Processing Record 13 of Set 9 | ust-tsilma
# Processing Record 14 of Set 9 | ucluelet
# Processing Record 15 of Set 9 | finschhafen
# Processing Record 16 of Set 9 | bambanglipuro
# Processing Record 17 of Set 9 | geraldton
# Processing Record 18 of Set 9 | guiratinga
# Processing Record 19 of Set 9 | pisco
# Processing Record 20 of Set 9 | kysyl-syr
# Processing Record 21 of Set 9 | sola
# Processing Record 22 of Set 9 | tabas
# Processing Record 23 of Set 9 | horsham
# Processing Record 24 of Set 9 | ancud
# Processing Record 25 of Set 9 | jinchang
# Processing Record 26 of Set 9 | ribas do rio pardo
# Processing Record 27 of Set 9 | kenai
# Processing Record 28 of Set 9 | langsa
# Processing Record 29 of Set 9 | airai
# Processing Record 30 of Set 9 | kununurra
# Processing Record 31 of Set 9 | puerto del rosario
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | kaeo
# Processing Record 34 of Set 9 | pangkalanbuun
# Processing Record 35 of Set 9 | amambai
# Processing Record 36 of Set 9 | churachandpur
# Processing Record 37 of Set 9 | uvat
# Processing Record 38 of Set 9 | lensk
# Processing Record 39 of Set 9 | haines junction
# Processing Record 40 of Set 9 | kyzyl-suu
# Processing Record 41 of Set 9 | baykit
# Processing Record 42 of Set 9 | auki
# Processing Record 43 of Set 9 | bereda
# Processing Record 44 of Set 9 | karratha
# Processing Record 45 of Set 9 | troitskoye
# Processing Record 46 of Set 9 | havre-saint-pierre
# Processing Record 47 of Set 9 | corowa
# Processing Record 48 of Set 9 | salamiyah
# Processing Record 49 of Set 9 | vila franca do campo
# Processing Record 50 of Set 9 | popondetta
# Processing Record 1 of Set 10 | buraydah
# Processing Record 2 of Set 10 | devonport
# Processing Record 3 of Set 10 | beipiao
# Processing Record 4 of Set 10 | amahai
# Processing Record 5 of Set 10 | ialibu
# Processing Record 6 of Set 10 | bandarbeyla
# Processing Record 7 of Set 10 | palmer
# Processing Record 8 of Set 10 | roxas
# Processing Record 9 of Set 10 | sadao
# Processing Record 10 of Set 10 | hofn
# Processing Record 11 of Set 10 | pasighat
# Processing Record 12 of Set 10 | nicoya
# Processing Record 13 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 14 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 10 | edremit
# Processing Record 16 of Set 10 | arroyo
# Processing Record 17 of Set 10 | kidal
# Processing Record 18 of Set 10 | dingle
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | taksimo
# Processing Record 21 of Set 10 | xiamen
# Processing Record 22 of Set 10 | tavai
# City not found. Skipping...
# Processing Record 23 of Set 10 | tuatapere
# Processing Record 24 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 25 of Set 10 | karaton
# Processing Record 26 of Set 10 | qandala
# Processing Record 27 of Set 10 | beloha
# Processing Record 28 of Set 10 | lexington park
# Processing Record 29 of Set 10 | bima
# Processing Record 30 of Set 10 | knysna
# Processing Record 31 of Set 10 | linxia
# Processing Record 32 of Set 10 | basse
# Processing Record 33 of Set 10 | kudahuvadhoo
# Processing Record 34 of Set 10 | el alto
# Processing Record 35 of Set 10 | okha
# Processing Record 36 of Set 10 | vao
# Processing Record 37 of Set 10 | luderitz
# Processing Record 38 of Set 10 | ulladulla
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | kutum
# Processing Record 41 of Set 10 | maningrida
# Processing Record 42 of Set 10 | tiarei
# Processing Record 43 of Set 10 | lasa
# Processing Record 44 of Set 10 | weyburn
# Processing Record 45 of Set 10 | kattivakkam
# Processing Record 46 of Set 10 | aksarka
# Processing Record 47 of Set 10 | qurayyat
# City not found. Skipping...
# Processing Record 48 of Set 10 | kodiak
# Processing Record 49 of Set 10 | lardos
# Processing Record 50 of Set 10 | san quintin
# Processing Record 1 of Set 11 | mamakan
# Processing Record 2 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 11 | snasa
# Processing Record 4 of Set 11 | teknaf
# Processing Record 5 of Set 11 | liwale
# Processing Record 6 of Set 11 | moyale
# Processing Record 7 of Set 11 | dayong
# Processing Record 8 of Set 11 | eyl
# Processing Record 9 of Set 11 | maralal
# Processing Record 10 of Set 11 | kosikha
# Processing Record 11 of Set 11 | tommot
# Processing Record 12 of Set 11 | petrykiv
# Processing Record 13 of Set 11 | chingirlau
# Processing Record 14 of Set 11 | kosh-agach
# Processing Record 15 of Set 11 | puerto ayacucho
# Processing Record 16 of Set 11 | ostrovnoy
# Processing Record 17 of Set 11 | iqaluit
# Processing Record 18 of Set 11 | solnechnyy
# Processing Record 19 of Set 11 | opuwo
# Processing Record 20 of Set 11 | kirakira
# Processing Record 21 of Set 11 | dukhovshchina
# Processing Record 22 of Set 11 | belmonte
# Processing Record 23 of Set 11 | jiexiu
# Processing Record 24 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 11 | ilinskiy
# Processing Record 26 of Set 11 | erzin
# Processing Record 27 of Set 11 | manyana
# Processing Record 28 of Set 11 | colesberg
# Processing Record 29 of Set 11 | wonthaggi
# Processing Record 30 of Set 11 | mahebourg
# Processing Record 31 of Set 11 | namie
# Processing Record 32 of Set 11 | jutai
# Processing Record 33 of Set 11 | santa flavia
# Processing Record 34 of Set 11 | vanavara
# Processing Record 35 of Set 11 | beringovskiy
# Processing Record 36 of Set 11 | saucillo
# Processing Record 37 of Set 11 | hay river
# Processing Record 38 of Set 11 | jatai
# Processing Record 39 of Set 11 | claremore
# Processing Record 40 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | dalvik
# Processing Record 42 of Set 11 | balabac
# Processing Record 43 of Set 11 | novosokolniki
# Processing Record 44 of Set 11 | praia da vitoria
# Processing Record 45 of Set 11 | nogliki
# Processing Record 46 of Set 11 | samarai
# Processing Record 47 of Set 11 | burgeo
# Processing Record 48 of Set 11 | gonbad-e qabus
# Processing Record 49 of Set 11 | hambantota
# Processing Record 50 of Set 11 | piacabucu
# Processing Record 1 of Set 12 | lorengau
# Processing Record 2 of Set 12 | sembe
# City not found. Skipping...
# Processing Record 3 of Set 12 | tautira
# Processing Record 4 of Set 12 | paris
# Processing Record 5 of Set 12 | wyndham
# Processing Record 6 of Set 12 | huilong
# Processing Record 7 of Set 12 | zastavna
# Processing Record 8 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 9 of Set 12 | tatui
# Processing Record 10 of Set 12 | prainha
# Processing Record 11 of Set 12 | mount gambier
# Processing Record 12 of Set 12 | shakawe
# Processing Record 13 of Set 12 | ferrol
# Processing Record 14 of Set 12 | syke
# Processing Record 15 of Set 12 | port huron
# Processing Record 16 of Set 12 | adeje
# Processing Record 17 of Set 12 | borogontsy
# Processing Record 18 of Set 12 | gornyy
# Processing Record 19 of Set 12 | kurumkan
# Processing Record 20 of Set 12 | rudnaya pristan
# Processing Record 21 of Set 12 | santa rosa
# Processing Record 22 of Set 12 | ishigaki
# Processing Record 23 of Set 12 | cavalcante
# Processing Record 24 of Set 12 | saint-joseph
# Processing Record 25 of Set 12 | kanelovskaya
# Processing Record 26 of Set 12 | huruta
# Processing Record 27 of Set 12 | rincon
# Processing Record 28 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of Set 12 | nome
# Processing Record 30 of Set 12 | oslo
# Processing Record 31 of Set 12 | berberati
# Processing Record 32 of Set 12 | marzuq
# Processing Record 33 of Set 12 | alexandria
# Processing Record 34 of Set 12 | ventspils
# Processing Record 35 of Set 12 | pionerskiy
# Processing Record 36 of Set 12 | teguise
# Processing Record 37 of Set 12 | salisbury
# Processing Record 38 of Set 12 | burica
# City not found. Skipping...
# Processing Record 39 of Set 12 | ciuperceni
# Processing Record 40 of Set 12 | meulaboh
# Processing Record 41 of Set 12 | mulanje
# Processing Record 42 of Set 12 | linqiong
# Processing Record 43 of Set 12 | nanchang
# Processing Record 44 of Set 12 | montrose
# Processing Record 45 of Set 12 | jalu
# Processing Record 46 of Set 12 | ingham
# Processing Record 47 of Set 12 | loreto
# Processing Record 48 of Set 12 | hvolsvollur
# City not found. Skipping...
# Processing Record 49 of Set 12 | vyartsilya
# Processing Record 50 of Set 12 | hobro
# Processing Record 1 of Set 13 | ilhabela
# Processing Record 2 of Set 13 | ende
# Processing Record 3 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 13 | constitucion
# Processing Record 5 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 13 | kahului
# Processing Record 7 of Set 13 | rocha
# Processing Record 8 of Set 13 | nemuro
# Processing Record 9 of Set 13 | flinders
# Processing Record 10 of Set 13 | flin flon
# Processing Record 11 of Set 13 | mayo
# Processing Record 12 of Set 13 | abu kamal
# Processing Record 13 of Set 13 | shangzhi
# Processing Record 14 of Set 13 | tullahoma
# Processing Record 15 of Set 13 | bullhead city
# Processing Record 16 of Set 13 | prince george
# Processing Record 17 of Set 13 | dongsheng
# Processing Record 18 of Set 13 | tha bo
# Processing Record 19 of Set 13 | kirkenaer
# Processing Record 20 of Set 13 | natal
# Processing Record 21 of Set 13 | vicksburg
# Processing Record 22 of Set 13 | kasongo
# Processing Record 23 of Set 13 | brigantine
# Processing Record 24 of Set 13 | xining
# Processing Record 25 of Set 13 | kota kinabalu
# Processing Record 26 of Set 13 | milazzo
# Processing Record 27 of Set 13 | mandalgovi
# Processing Record 28 of Set 13 | jinan
# Processing Record 29 of Set 13 | akdepe
# Processing Record 30 of Set 13 | tyup
# Processing Record 31 of Set 13 | antigonish
# Processing Record 32 of Set 13 | santana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Port Alfred -33.59   26.89     69.01        90          50
# 1                Bluff -23.58  149.07     74.39        77           0
# 2              Mataura -46.19  168.86     52.00        72          87
# 3        Mar Del Plata -46.43  -67.52     69.57        33         100
# 4              Ushuaia -54.81  -68.31     50.00        66          75
# 5       Saint-Philippe  45.36  -73.48     23.00        73          90
# 6         Kruisfontein -34.00   24.73     65.17        83         100
# 7              Rikitea -23.12 -134.97     76.03        78          67
# 8  Nuevo Casas Grandes  30.42 -107.91     63.88        22           0
# 9            Vera Cruz -12.96  -38.61     80.60        83          75
#
#    Wind Speed Country Current Description  Rain inches (last 3 hrs)  \
# 0        1.01      ZA    scattered clouds                      0.00
# 1       10.36      AU           clear sky                      0.00
# 2       25.01      NZ          light rain                      1.56
# 3        6.33      AR     overcast clouds                      0.00
# 4       25.28      AR       broken clouds                      0.00
# 5        8.05      CA     overcast clouds                      0.00
# 6        5.23      ZA          light rain                      0.19
# 7       15.41      PF       broken clouds                      0.00
# 8        4.79      MX           clear sky                      0.00
# 9       12.75      BR       broken clouds                      0.00
#
#    Snow inches (last 3 hrs)                 Date
# 0                       0.0  2020-01-05 21:59:38
# 1                       0.0  2020-01-05 22:00:17
# 2                       0.0  2020-01-05 21:57:03
# 3                       0.0  2020-01-05 21:58:09
# 4                       0.0  2020-01-05 21:58:03
# 5                       0.0  2020-01-05 22:00:34
# 6                       0.0  2020-01-05 22:00:57
# 7                       0.0  2020-01-05 22:00:18
# 8                       0.0  2020-01-05 22:04:37
# 9                       0.0  2020-01-05 22:04:37

# %%
# Reorder the Columns like this City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed.
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description","Rain inches (last 3 hrs)","Snow inches (last 3 hrs)"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#                   City Country                 Date    Lat     Lng  Max Temp  \
# 0          Port Alfred      ZA  2020-01-05 21:59:38 -33.59   26.89     69.01
# 1                Bluff      AU  2020-01-05 22:00:17 -23.58  149.07     74.39
# 2              Mataura      NZ  2020-01-05 21:57:03 -46.19  168.86     52.00
# 3        Mar Del Plata      AR  2020-01-05 21:58:09 -46.43  -67.52     69.57
# 4              Ushuaia      AR  2020-01-05 21:58:03 -54.81  -68.31     50.00
# 5       Saint-Philippe      CA  2020-01-05 22:00:34  45.36  -73.48     23.00
# 6         Kruisfontein      ZA  2020-01-05 22:00:57 -34.00   24.73     65.17
# 7              Rikitea      PF  2020-01-05 22:00:18 -23.12 -134.97     76.03
# 8  Nuevo Casas Grandes      MX  2020-01-05 22:04:37  30.42 -107.91     63.88
# 9            Vera Cruz      BR  2020-01-05 22:04:37 -12.96  -38.61     80.60
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        90          50        1.01    scattered clouds
# 1        77           0       10.36           clear sky
# 2        72          87       25.01          light rain
# 3        33         100        6.33     overcast clouds
# 4        66          75       25.28       broken clouds
# 5        73          90        8.05     overcast clouds
# 6        83         100        5.23          light rain
# 7        78          67       15.41       broken clouds
# 8        22           0        4.79           clear sky
# 9        83          75       12.75       broken clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                       0.0
# 1                      0.00                       0.0
# 2                      1.56                       0.0
# 3                      0.00                       0.0
# 4                      0.00                       0.0
# 5                      0.00                       0.0
# 6                      0.19                       0.0
# 7                      0.00                       0.0
# 8                      0.00                       0.0
# 9                      0.00                       0.0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# How many cities have recorded rainfall
rain_count = city_data_df.loc[(city_data_df)["Rain inches (last 3 hrs)"]!=0].count()
rain_count
# Out:
# City                        58
# Country                     58
# Date                        58
# Lat                         58
# Lng                         58
# Max Temp                    58
# Humidity                    58
# Cloudiness                  58
# Wind Speed                  58
# Current Description         58
# Rain inches (last 3 hrs)    58
# Snow inches (last 3 hrs)    58
# dtype: int64

# %%
# How many cities have recorded rainfall
snow_count = city_data_df.loc[(city_data_df)["Snow inches (last 3 hrs)"]!=0].count()
snow_count
# Out:
# City                        21
# Country                     21
# Date                        21
# Lat                         21
# Lng                         21
# Max Temp                    21
# Humidity                    21
# Cloudiness                  21
# Wind Speed                  21
# Current Description         21
# Rain inches (last 3 hrs)    21
# Snow inches (last 3 hrs)    21
# dtype: int64
